# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/diabtesupdated.csv

# %%
data= pd.read_csv("../input/diabtesupdated.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.507812
# std      7.884160                  0.331329   11.760232    0.753915
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True)

# %%
sns.distplot(data['Glucose'],kde=True, bins=10)

# %%
sns.distplot(data['Insulin'],kde=True, bins=10,color='green')

# %%
sns.distplot(data['BMI'],kde=True, bins=10)

# %%
sns.distplot(data['Pregnancies'],kde=True, bins=10,color='orange')

# %%
sns.countplot(data['Outcome'],label="Count")

# %%
median_bmi = data['BMI'].median()
mean_bmi=data['BMI'].mean()
print("The median BMI is :",median_bmi)
print("The mean BMI is :",mean_bmi)
# Out:
# The median BMI is : 32.0
# The mean BMI is : 31.992578124999977

# %%
median_bp=data['BloodPressure'].median()
mean_bp=data['BloodPressure'].mean()
print('Median Blood Pressure is:',median_bp)
print('Mean Blood Preddure is :',mean_bp)
# Out:
# Median Blood Pressure is: 72.0
# Mean Blood Preddure is : 69.10546875

# %%
median_insulin=data['Insulin'].median()
mean_insulin=data['Insulin'].mean()
print('Median Insulin is:',median_insulin)
print('Mean Insulin is :',mean_insulin)
# Out:
# Median Insulin is: 30.5
# Mean Insulin is : 79.79947916666667

# %%
median_skin=data['SkinThickness'].median()
mean_skin=data['SkinThickness'].mean()
print('Median Skin Thickness is:',median_skin)
print('Mean SkinThickness is :',mean_skin)
# Out:
# Median Skin Thickness is: 23.0
# Mean SkinThickness is : 20.536458333333332

# %%
median_preg=data['Pregnancies'].median()
mean_preg=data['Pregnancies'].mean()
print('Median Pregnancy is:',median_preg)
print('Mean Pregnancy is :',mean_preg)
# Out:
# Median Pregnancy is: 3.0
# Mean Pregnancy is : 3.8450520833333335

# %%
median_age=data['Age'].median()
mean_age=data['Age'].mean()
print('Median Age is:',median_age)
print('Mean Age is :',mean_age)
# Out:
# Median Age is: 29.0
# Mean Age is : 33.240885416666664

# %%
median_glucose=data['Glucose'].median()
mean_glucose=data['Glucose'].mean()
print('Median Glucose is:',median_glucose)
print('Mean Glucose is :',mean_glucose)
# Out:
# Median Glucose is: 117.0
# Mean Glucose is : 120.89453125

# %%
median_DiabetesPedigreeFunction=data['DiabetesPedigreeFunction'].median()
mean_DiabetesPedigreeFunction=data['DiabetesPedigreeFunction'].mean()
print('Median DiabetesPedigreeFunction is:',median_DiabetesPedigreeFunction)
print('Mean DiabetesPedigreeFunction is :',mean_DiabetesPedigreeFunction)
# Out:
# Median DiabetesPedigreeFunction is: 0.3725
# Mean DiabetesPedigreeFunction is : 0.4718763020833327

# %%
data['BMI'] = data['BMI'].replace(
    to_replace=0, value=median_bmi)
data['DiabetesPedigreeFunction'] = data['DiabetesPedigreeFunction'].replace(
    to_replace=0, value=median_DiabetesPedigreeFunction)
data['Glucose'] = data['Glucose'].replace(
    to_replace=0, value=median_glucose)
data['Age'] = data['Age'].replace(
    to_replace=0, value=median_age)
data['Pregnancies'] = data['Pregnancies'].replace(
    to_replace=0, value=median_preg)
data['SkinThickness'] = data['SkinThickness'].replace(
    to_replace=0, value=median_skin)
data['Insulin'] = data['Insulin'].replace(
    to_replace=0, value=median_insulin)
data['BloodPressure'] = data['BloodPressure'].replace(
    to_replace=0, value=median_bp)

# %%
plt.figure(figsize=(50,25))
sns.barplot(x=data['Glucose'],y=data['Insulin'])
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.title('Relation between Insulin and Glucose')
# Out:
# Text(0.5, 1.0, 'Relation between Insulin and Glucose')

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=data['Glucose'],label='Glucose')
sns.lineplot(data=data['Insulin'],label='Insulin')

sns.swarmplot(x=data['Glucose'],y=data['Insulin'])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Outcome', axis=1)
Y = data['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)
numerical_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['int64', 'float64']]
categorical_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['object']]

# %%
numerical_transformer = SimpleImputer(strategy='constant')
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
preprocessor = ColumnTransformer(
    transformers=[
        ('num ', numerical_transformer, numerical_cols),
        ('cat ', categorical_transformer, categorical_cols)
    ])

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=1000, random_state=0)

# %%
from sklearn.metrics import mean_absolute_error,accuracy_score
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)
                             ])

my_pipeline.fit(X_train, y_train)

preds = my_pipeline.predict(X_test)

score = mean_absolute_error(y_test, preds)
print('MAE:', score)
# Out:
# MAE: 0.4090909090909091

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,preds))
# Out:
# [[82  6  3]
#  [19 15  0]
#  [16  0 13]]

# %%
from sklearn.metrics import classification_report
print(accuracy_score(y_test,preds)*100)
print(classification_report(y_test,preds))
# Out:
# 71.42857142857143
#               precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79        91
#            1       0.71      0.44      0.55        34
#            2       0.81      0.45      0.58        29
#
#     accuracy                           0.71       154
#    macro avg       0.74      0.60      0.64       154
# weighted avg       0.72      0.71      0.70       154

# %%
df = pd.DataFrame({'  Actual Type of Diabetes ': y_test, '   Predicted Type of Diabetes': preds})
df1 = df.head(50)
print(df1)
# Out:
#        Actual Type of Diabetes      Predicted Type of Diabetes
# 441                           0                              0
# 299                           0                              0
# 603                           2                              2
# 483                           0                              0
# 362                           0                              0
# 115                           1                              0
# 700                           0                              0
# 271                           0                              0
# 265                           0                              0
# 633                           0                              0
# 136                           0                              0
# 548                           0                              1
# 240                           0                              0
# 602                           0                              0
# ...

# %%
df1.plot(kind='bar',figsize=(20,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
import shap 
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values[1], X_test)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
y = data['Outcome'] 
feature_names=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
#tree_model = DecisionTreeClassifier(random_state=0, max_depth=9, min_samples_split=5).fit(train_X, train_y)

# %%
tree_model = DecisionTreeClassifier(random_state=0, max_depth=8, min_samples_split=8).fit(train_X, train_y)

# %%
from sklearn.metrics import confusion_matrix
y_pred = tree_model.predict(val_X)
print(confusion_matrix(val_y, y_pred))
# Out:
# [[105   9   9]
#  [ 19  19   0]
#  [  8   0  23]]

# %%
print(accuracy_score(val_y,y_pred)*100)
print(classification_report(val_y,y_pred))
# Out:
# 76.5625
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       123
#            1       0.68      0.50      0.58        38
#            2       0.72      0.74      0.73        31
#
#     accuracy                           0.77       192
#    macro avg       0.73      0.70      0.71       192
# weighted avg       0.76      0.77      0.76       192

# %%
from sklearn import tree
import graphviz
plt.figure(figsize=(2,2))
tree_graph = tree.export_graphviz(tree_model, out_file=None, feature_names=feature_names)
graphviz.Source(tree_graph)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(val_y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(val_y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(val_y, y_pred)))
# Out:
# Mean Absolute Error: 0.3229166666666667
# Mean Squared Error: 0.5
# Root Mean Squared Error: 0.7071067811865476

# %%
import shap 
explainer = shap.TreeExplainer(tree_model)
shap_values = explainer.shap_values(val_X)
shap.summary_plot(shap_values[1], val_X)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
df = pd.DataFrame({'  Actual Type of Diabetes ': val_y, '   Predicted Type of Diabetes': y_pred})
df1 = df.head(50)
print(df1)
# Out:
#        Actual Type of Diabetes      Predicted Type of Diabetes
# 285                           0                              2
# 101                           0                              1
# 581                           0                              0
# 352                           0                              0
# 726                           0                              0
# 472                           0                              0
# 233                           0                              0
# 385                           0                              0
# 556                           0                              0
# 59                            0                              2
# 756                           0                              1
# 341                           0                              0
# 445                           1                              1
# 614                           2                              2
# ...

# %%
df1.plot(kind='bar',figsize=(20,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
model2=LogisticRegression(C=1000,random_state=42)
model2.fit(train_X,train_y)
# Out:
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logreg_pred=model2.predict(val_X)

# %%
df2 = pd.DataFrame({'  Actual Quality ': val_y, '   Predicted Quality': logreg_pred})
df3 = df.head(25)
print(df3)
# Out:
#        Actual Type of Diabetes      Predicted Type of Diabetes
# 285                           0                              2
# 101                           0                              1
# 581                           0                              0
# 352                           0                              0
# 726                           0                              0
# 472                           0                              0
# 233                           0                              0
# 385                           0                              0
# 556                           0                              0
# 59                            0                              2
# 756                           0                              1
# 341                           0                              0
# 445                           1                              1
# 614                           2                              2
# ...

# %%
df3.plot(kind='bar',figsize=(20,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print("The accuracy score is :",accuracy_score(val_y,logreg_pred)*100,"%")
# Out:
# The accuracy score is : 69.79166666666666 %

# %%
print(classification_report(val_y, logreg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.78       123
#            1       0.59      0.58      0.59        38
#            2       0.60      0.39      0.47        31
#
#     accuracy                           0.70       192
#    macro avg       0.65      0.59      0.61       192
# weighted avg       0.69      0.70      0.69       192

# %%
print(confusion_matrix(val_y, logreg_pred))
# Out:
# [[100  15   8]
#  [ 16  22   0]
#  [ 19   0  12]]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(val_y, logreg_pred))
print('Mean Squared Error:', metrics.mean_squared_error(val_y, logreg_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(val_y, logreg_pred)))
# Out:
# Mean Absolute Error: 0.4427083333333333
# Mean Squared Error: 0.7239583333333334
# Root Mean Squared Error: 0.8508574106942557

# %%
from sklearn.svm import LinearSVC     #Using support vector classifier
model3 = LinearSVC(C=1000,random_state=0)
model3.fit(train_X, train_y)
# Out:
# Liblinear failed to converge, increase the number of iterations.
# LinearSVC(C=1000, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#           verbose=0)

# %%
svc_pred=model3.predict(val_X)

# %%
print(confusion_matrix(val_y,svc_pred))
# Out:
# [[95  3 25]
#  [21 17  0]
#  [ 5  0 26]]

# %%
print("The accuracy of the model is :" ,accuracy_score(val_y, svc_pred)*100)
# Out:
# The accuracy of the model is : 71.875

# %%
df4 = pd.DataFrame({'  Actual Quality ': val_y, '   Predicted Quality': svc_pred})
df5 = df.head(25)
print(df5)
# Out:
#        Actual Type of Diabetes      Predicted Type of Diabetes
# 285                           0                              2
# 101                           0                              1
# 581                           0                              0
# 352                           0                              0
# 726                           0                              0
# 472                           0                              0
# 233                           0                              0
# 385                           0                              0
# 556                           0                              0
# 59                            0                              2
# 756                           0                              1
# 341                           0                              0
# 445                           1                              1
# 614                           2                              2
# ...

# %%
df5.plot(kind='bar',figsize=(20,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print(classification_report(val_y,svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78       123
#            1       0.85      0.45      0.59        38
#            2       0.51      0.84      0.63        31
#
#     accuracy                           0.72       192
#    macro avg       0.71      0.69      0.67       192
# weighted avg       0.75      0.72      0.72       192

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(val_y, svc_pred))
print('Mean Squared Error:', metrics.mean_squared_error(val_y, svc_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(val_y, svc_pred)))
# Out:
# Mean Absolute Error: 0.4375
# Mean Squared Error: 0.75
# Root Mean Squared Error: 0.8660254037844386

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNclassifier = KNeighborsClassifier(n_neighbors=15)
KNNclassifier.fit(train_X, train_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='uniform')

# %%
KNN_pred = KNNclassifier.predict(val_X)

# %%
print(confusion_matrix(val_y, KNN_pred))
# Out:
# [[107   7   9]
#  [ 15  23   0]
#  [ 10   0  21]]

# %%
print(classification_report(val_y,KNN_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       123
#            1       0.77      0.61      0.68        38
#            2       0.70      0.68      0.69        31
#
#     accuracy                           0.79       192
#    macro avg       0.76      0.72      0.73       192
# weighted avg       0.78      0.79      0.78       192

# %%
print('Accuracy score is :',accuracy_score(val_y,KNN_pred)*100)
# Out:
# Accuracy score is : 78.64583333333334

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(val_y, KNN_pred))
print('Mean Squared Error:', metrics.mean_squared_error(val_y, 
                                                        KNN_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(val_y, KNN_pred)))
# Out:
# Mean Absolute Error: 0.3125
# Mean Squared Error: 0.5104166666666666
# Root Mean Squared Error: 0.7144345083117603

# %%
df6 = pd.DataFrame({'  Actual Quality ': val_y, '   Predicted Quality': KNN_pred})
df7 = df.head(157)
print(df7)
# Out:
#        Actual Type of Diabetes      Predicted Type of Diabetes
# 285                           0                              2
# 101                           0                              1
# 581                           0                              0
# 352                           0                              0
# 726                           0                              0
# ..                          ...                            ...
# 684                           0                              0
# 643                           0                              0
# 663                           2                              2
# 712                           1                              1
# 161                           0                              0
#
# [157 rows x 2 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib
#matplotlib.use('GTK3Agg')
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
h=.02
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA','#00AAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00','#00AAFF'])
KNNclassifier = KNeighborsClassifier(n_neighbors=15,weights='distance')
KNNclassifier.fit(train_X, train_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='distance')

# %%
iris =  pd.read_csv("../input/diabtesupdated.csv")
iris_data = iris.iloc[:, :-1].values
iris_labels = iris.iloc[:,8].values
print(iris_data[0], iris_data[79], iris_data[100])
print(iris_labels[0], iris_labels[79], iris_labels[100])
# Out:
# [  6.    148.     72.     35.      0.     33.6     0.627  50.   ] [  2.    112.     66.     22.      0.     25.      0.307  24.   ] [  1.    163.     72.      0.      0.     39.      1.222  33.   ]
# 1 0 1

# %%
np.random.seed(42)
indices = np.random.permutation(len(iris_data))
n_training_samples = 15
learnset_data = iris_data[indices[:-n_training_samples]]
learnset_labels = iris_labels[indices[:-n_training_samples]]
testset_data = iris_data[indices[-n_training_samples:]]
testset_labels = iris_labels[indices[-n_training_samples:]]
print(learnset_data[:4], learnset_labels[:4])
print(testset_data[:4], testset_labels[:4])
# Out:
# [[6.00e+00 9.80e+01 5.80e+01 3.30e+01 1.90e+02 3.40e+01 4.30e-01 4.30e+01]
#  [2.00e+00 1.12e+02 7.50e+01 3.20e+01 0.00e+00 3.57e+01 1.48e-01 2.10e+01]
#  [2.00e+00 1.08e+02 6.40e+01 0.00e+00 0.00e+00 3.08e+01 1.58e-01 2.10e+01]
#  [8.00e+00 1.07e+02 8.00e+01 0.00e+00 0.00e+00 2.46e+01 8.56e-01 3.40e+01]] [0 0 0 0]
# [[  0.     84.     64.     22.     66.     35.8     0.545  21.   ]
#  [  2.    100.     68.     25.     71.     38.5     0.324  26.   ]
#  [ 10.    148.     84.     48.    237.     37.6     1.001  51.   ]
#  [  8.    118.     72.     19.      0.     23.1     1.476  46.   ]] [0 0 2 0]

# %%
# %matplotlib inline 

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#colours = ("r", "b")
X = []
for iclass in range(3):
    X.append([[], [], []])
    for i in range(len(learnset_data)):
        if learnset_labels[i] == iclass:
            X[iclass][0].append(learnset_data[i][0])
            X[iclass][1].append(learnset_data[i][1])
            X[iclass][2].append(sum(learnset_data[i][2:]))

colours = ("r", "green", "b")

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
for iclass in range(3):
       ax.scatter(X[iclass][0], X[iclass][1], X[iclass][2], c=colours[iclass])
plt.show()

# %%
df7.plot(kind='bar',figsize=(20,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
error = []
# Calculating error for K values between 1 and 40
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='black', linestyle='dashed', marker='.',
         markerfacecolor='black', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=500,random_state=42)
xgb_model.fit(train_X, train_y,early_stopping_rounds=5, 
             eval_set=[(val_X, val_y)],
             verbose=False)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
predictions = xgb_model.predict(val_X)
print("Mean Absolute Error: " + str(mean_absolute_error(predictions, val_y)))
# Out:
# Mean Absolute Error: 0.24479166666666666

# %%
print('Accuracy_score :',accuracy_score(val_y,predictions)*100)
# Out:
# Accuracy_score : 81.25

# %%
print(classification_report(val_y,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       123
#            1       0.72      0.55      0.63        38
#            2       0.86      0.77      0.81        31
#
#     accuracy                           0.81       192
#    macro avg       0.80      0.74      0.77       192
# weighted avg       0.81      0.81      0.81       192

# %%
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(val_X)
shap.summary_plot(shap_values[1], val_X)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
print(confusion_matrix(val_y,predictions))
# Out:
# [[111   8   4]
#  [ 17  21   0]
#  [  7   0  24]]
